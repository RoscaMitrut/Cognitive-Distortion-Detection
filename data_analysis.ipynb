# %% [markdown]
# patient question , distorted part , dominant distortion , secondary distortion , therapist answer
#
# - Ca date avem intrebarea unui pacient pusa unui terapist, si raspunsul acestuia, partea distorsionata din intrebare si tipul distorsiunii.
# - Scop: Stabilirea distorsiunilor unui individ/ stabilirea prezentei unei distorsiuni, bazat pe intrebarea pe care acesta o pune terapeutului

# %%
import pandas as pd
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
nltk.download('stopwords')
import matplotlib.pyplot as plt
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\RoscaMitrut\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
annotated_data_copy = pd.read_csv("data/Annotated_data.csv",delimiter=",")
annotated_data_copy[:5]
# Out:
#    Id_Number                                   Patient Question  \
# 0       4500  Hello, I have a beautiful,smart,outgoing and a...
# 1       4501  Since I was about 16 years old I’ve had these ...
# 2       4502   So I’ve been dating on and off this guy for a...
# 3       4503  My parents got divorced in 2004. My mother has...
# 4       4504  I don’t really know how to explain the situati...
#
#                                       Distorted part Dominant Distortion  \
# 0  The voice are always fimilar (someone she know...     Personalization
# 1  I feel trapped inside my disgusting self and l...            Labeling
# 2                                                NaN       No Distortion
# 3                                                NaN       No Distortion
# 4  I refused to go because I didn’t know if it wa...     Fortune-telling
#
#   Secondary Distortion (Optional)
# 0                             NaN
# 1             Emotional Reasoning
# 2                             NaN
# ...

# %%
annotated_data_copy["Dominant Distortion"].value_counts()
# Out:
# Dominant Distortion
# No Distortion              933
# Mind Reading               239
# Overgeneralization         239
# Magnification              195
# Labeling                   165
# Personalization            153
# Fortune-telling            143
# Emotional Reasoning        134
# Mental filter              122
# Should statements          107
# All-or-nothing thinking    100
# Name: count, dtype: int64

# %%
plt.plot([el.count(" ") for el in annotated_data_copy["Patient Question"]])
plt.xlabel("Question ID")
plt.ylabel("Approximate Word Count")
plt.plot()
# WORD COUNT PER QUESTION BEFORE REMOVING STOPWORDS
# Out:
# []

# %%
def remove_stop_words(text):
    text = word_tokenize(text.lower())
    stop_words = set(stopwords.words('english'))
    text = [word for word in text if word.isalpha() and not word in stop_words]
    return ' '.join(text)

texts = annotated_data_copy["Patient Question"].tolist()

sentences = list(map(remove_stop_words,texts))

# %%
plt.plot([el.count(" ") for el in sentences])
plt.xlabel("Question ID")
plt.ylabel("Approximate Word Count After Removal")
plt.plot()
# WORD COUNT PER QUESTION AFTER REMOVING STOPWORDS
# Out:
# []
